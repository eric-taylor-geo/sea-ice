# %%
from data import get_train_test_arrays

X_train, y_train, X_test, y_test = get_train_test_arrays(
    patch_size=128,
    train_patches_per_scene=500,
    test_patches_per_scene=200,
    seed=42,
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3500, 128, 128, 2) (3500, 128, 128, 1)
# (200, 128, 128, 2) (200, 128, 128, 1)

# %%
import torch

# %%
from models import UNet

model = UNet(in_channels=2, out_channels=1)
model.load_state_dict(torch.load("../weights/unet_sea_ice.pth", map_location=torch.device('cpu') if not torch.cuda.is_available() else torch.device('cuda')))
# Out:
# <All keys matched successfully>
